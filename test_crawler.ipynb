# %% [markdown]
# # 下記で、参加予定者のGithubのリンクを取得する

# %%
import requests
from bs4 import BeautifulSoup

def get_github_links_from_connpass_participants(url):
    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    res = requests.get(url, headers=headers)
    res.raise_for_status()

    soup = BeautifulSoup(res.text, "html.parser")

    github_links = []

    # GitHubアイコン画像を探して、親の<a>からhrefを取得
    for img in soup.select("img[alt='GitHubを見る']"):
        parent_link = img.find_parent("a")
        if parent_link and parent_link.get("href", "").startswith("https://github.com/"):
            github_links.append(parent_link["href"])

    return github_links

# ✅ 実行例
event_url = "https://gotalk.connpass.com/event/355423/participation/#participants"
github_profiles = get_github_links_from_connpass_participants(event_url)

print(f"{len(github_profiles)}人のGitHubプロフィールが見つかりました：")
for url in github_profiles:
    print(url)
# Out:
# 22人のGitHubプロフィールが見つかりました：
# https://github.com/sgash708
# https://github.com/otakakot
# https://github.com/takak2166
# https://github.com/nmatsumoto4
# https://github.com/syumai
# https://github.com/sgash708
# https://github.com/otakakot
# https://github.com/m-megmog-m
# https://github.com/logica0419
# https://github.com/takak2166
# https://github.com/Shion1305
# https://github.com/mazrean
# https://github.com/matumoto1234
# https://github.com/naoyafurudono
# https://github.com/nmatsumoto4
# https://github.com/syumai
# https://github.com/Shuhei-pp
# https://github.com/K-Kizuku
# https://github.com/mochi-yu
# https://github.com/AnDeriens
# https://github.com/shimabox
# https://github.com/take0fit

# %% [markdown]
# # HTMLをまるっと取得する

# %%
import requests

url = "https://gotalk.connpass.com/event/355423/participation/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
                   (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

res = requests.get(url, headers=headers)
html = res.text

print(html)  # ← HTML全文が取れるはず
# Out:
# <!DOCTYPE html>
# <!--
#
#
#    _|_|_|    _|_|    _|_|_|    _|_|_|    _|_|_|      _|_|_|    _|_|_|    _|_|_|
#  _|        _|    _|  _|    _|  _|    _|  _|    _|  _|    _|  _|_|      _|_|
#  _|        _|    _|  _|    _|  _|    _|  _|    _|  _|    _|      _|_|      _|_|
#    _|_|_|    _|_|    _|    _|  _|    _|  _|_|_|      _|_|_|  _|_|_|    _|_|_|
#                                          _|
#                                          _|
# -->
# <html lang="ja" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml">
# <head>
#
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
# <meta name="keywords" content="connpass,コンパス,イベント,IT勉強会,検索,開催,募集,参加,ソーシャル連携,アクセス解析,手数料無料" />
# <meta name="description" content="「Go Connect #7」の参加者・申込者の一覧です。" />
# <title>Go Connect #7 - 参加者・申込者一覧 - connpass</title>
#
#
# <link type="text/css" href="https://connpass.com/static/css/connpass.css?20250605010849
# " rel="stylesheet" media="all" />
#
#
#
#
#
# <meta property="og:type" content="website" />
# <meta property="og:site_name" content="connpass" />
# <meta property="fb:app_id" content="259235460759625" />
#
# <meta property="og:url" content="https://gotalk.connpass.com/event/355423/participation/" />
#
# <meta property="og:image" content="https://connpass.com/static/img/468_468.png" />
#
# <meta itemprop="image" content="https://connpass.com/static/img/72_72.png" />
#
# <meta property="og:title" content="connpass - エンジニアをつなぐIT勉強会支援プラットフォーム" />
# <meta property="og:description" content="connpassはイベントやIT勉強会の開催、さらに参加者の集客に便利です。コミュニティやグループの運営やイベントの検索、事前決済もできます。" />
# <meta itemprop="name" content="connpass - エンジニアをつなぐIT勉強会支援プラットフォーム" />
# <meta itemprop="description" content="connpassはイベントやIT勉強会の開催、さらに参加者の集客に便利です。コミュニティやグループの運営やイベントの検索、事前決済もできます。" />
#
#
#
#
#
#
#
#
# <link rel="shortcut icon" href="https://connpass.com/static/img/favicon.ico" type="image/vnd.microsoft.icon" />
# <link rel="apple-touch-icon-precomposed" href="https://connpass.com/static/img/apple_touch_icon.png" />
#
# <link rel="preload" as="style" type="text/css" onload="this.onload=null;this.rel='stylesheet'" href="https://fonts.googleapis.com/css?family=Montserrat&display=swap" >
#
# <script type="text/javascript">
#   if (typeof console == "undefined") {window.console={log: function () {}};console.warn = console.debug = console.log;}
# </script>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PJVQZGK');</script>
# <!-- End Google Tag Manager -->
#
#
#
#
#
#
# <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-4284859758109215" crossorigin="anonymous"></script>
#
# <script type="application/javascript" src="//anymind360.com/js/279/ats.js"></script>
#
# <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
#
# <script type="text/javascript">
# var path_value = location.pathname.substr(0,40);
# var parameter_value = location.search.substr(0, 40);
# var ref_value = "null";
# if (document.referrer){
# var ref_array=new Array();
# ref_array=document.referrer.split("/");
# ref_value = ref_array[2];}
# </script>
#
# <script>
#   googletag.cmd.push(function() {
#
#
#
#
# googletag.defineSlot('/21614746198/connpass_SP_banner_underTitle', [[1, 1], [320, 100], [320, 180], [300, 250]], 'div-gpt-ad-1506474705701-0').addService(googletag.pubads());
#
#
#     googletag.pubads().setTargeting('URLs', path_value).setTargeting('Ref', ref_value).setTargeting('Para', parameter_value);
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().collapseEmptyDivs();
#     googletag.enableServices();
#   });
# </script>
#
#
# </head>
#
# <body hx-headers='{"X-CSRFToken": "RRDNTC9LPznM89jmTXIy7f5BatOCXYJ1UC6vTKqqEX2DwEL84JGc0XLBmvJUokc1"}' class="event_participation">
#
# <div id="wrapper" class="lang_ja">
#
#   <div id="header">
#     <div class="container">
#       <h1><a href="https://connpass.com/" title="connpass - エンジニアをつなぐIT勉強会支援プラットフォーム"><img src="https://connpass.com/static/img/common/sitelogo_266x132_bp.png" alt="connpass - エンジニアをつなぐIT勉強会支援プラットフォーム" class="logo"></a></h1>
#
#
#         <form action="https://connpass.com/search/" method="GET" id="header_event_search_form">
#           <div class="header_search">
#             <input type="text" class="form_input_text" name="q" id="id_q" value="" placeholder="イベント検索">
#             <input type="hidden" name="start_from" value="2025/06/07">
#             <input type="hidden" name="start_to" value="2025/12/07">
#             <button type="submit" class="btn btn_default btn_size_small"><img src="https://connpass.com/static/img/common/icon_search.png" alt="イベント検索"></button>
#           </div>
#         </form>
#
#
#
#         <div class="header_nav_contents">
#           <ul>
#
#             <li><a href="https://connpass.com/explore/">新着イベント</a></li>
#           </ul>
#         </div>
#
#
#             <div class="header_nav_login">
#               <a class="btn btn_default login" href="https://connpass.com/login/">ログイン・新規登録</a>
#             </div>
#
#
#
#
#
#     </div>
#   </div>
#
#
#
#
#
#
#
#
#
# <div id="contents" class="container main_side_column">
#   <div id="flash_message_area" style="display: none;">
#
#   </div>
#
#
#   <div class="flex-row">
#
#
#       <div id="main">
#
# <div class="title_with_thumb mb_20">
#   <span class="thumbnail">
#     <a href="https://connpass.com/event/355423/" title="Go Connect #7">
#
#      <img src="https://media.connpass.com/thumbs/4d/4b/4d4b83b92b8ac11b23a15534b7bf4b99.png" width="48" height="48" alt="Go Connect #7">
#
#     </a>
#   </span>
#   <a href="https://gotalk.connpass.com/event/355423/" class="event_title"><span class="icon_red_four_right"></span>Go Connect #7</a>
#   <h2 class="page_title">イベント参加者・申込者一覧</h2>
# </div>
#
#
#
# <div class="adsense_sec">
#
# <p>広告</p>
#
#
#   <div id='div-gpt-ad-1506474705701-0'>
#   <script>
#   googletag.cmd.push(function() { googletag.display('div-gpt-ad-1506474705701-0'); });
#   </script>
#   </div>
#
#
# </div>
#
#
# <div class="concerned_area mb_30">
#   <h3 class="title_bg mb_10">イベント関係者</h3>
#
#   <table class="common_table participants_table padding_10">
#     <thead>
#       <tr>
#         <th colspan="2">管理者<span class="participants_count">2人</span></th>
#       </tr>
#     </thead>
#     <tbody>
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/chiroruxx/open/">
#
#             <img src="https://media.connpass.com/thumbs/fe/b1/feb1b52f9c521bda8524768f806755fa.png" alt="ちひろ" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/chiroruxx/open/">ちひろ</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/sgash708/open/">
#
#             <img src="https://media.connpass.com/thumbs/82/b8/82b8240f70a8aeead790a028601b7aa1.png" alt="Sugar Sato" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/sgash708/open/">Sugar Sato</a>
#
#
#       </p>
#       <p class="user_profile">SWE</p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=satoIsSugar" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/sgash708" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#     </tbody>
#
#
#
#     <thead>
#       <tr>
#         <th colspan="2">
#
#             発表者<span class="participants_count">5人</span>
#
#           <small>（connpassユーザーのみ表示しています）</small>
#         </th>
#       </tr>
#     </thead>
#     <tbody>
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/otakakot/presentation/">
#
#             <img src="https://media.connpass.com/thumbs/65/92/65929cfa046ecf845c723ebcc276eb34.png" alt="おーたかこーたろー" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/otakakot/presentation/">おーたかこーたろー</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=otakakot" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/otakakot" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/takak2166/presentation/">
#
#             <img src="https://media.connpass.com/thumbs/ed/14/ed144fc56ef76b6dcb87ee845047e2fd.png" alt="kashiwa" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/takak2166/presentation/">kashiwa</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/takak2166" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/chiroruxx/presentation/">
#
#             <img src="https://media.connpass.com/thumbs/fe/b1/feb1b52f9c521bda8524768f806755fa.png" alt="ちひろ" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/chiroruxx/presentation/">ちひろ</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/nmatsumoto4/presentation/">
#
#             <img src="https://media.connpass.com/thumbs/4c/d0/4cd02e74804f71b52c0fddfe73da4aaf.png" alt="nmatsumoto4" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/nmatsumoto4/presentation/">nmatsumoto4</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#           <span><img src="https://connpass.com/static/img/common/icon_facebook.png" alt="facebook" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/nmatsumoto4" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/syumai/presentation/">
#
#             <img src="https://media.connpass.com/thumbs/1c/c4/1cc4a993fa40fe5eb529f261e4387bfc.png" alt="syumai" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/syumai/presentation/">syumai</a>
#
#
#       </p>
#       <p class="user_profile">Go, React, Denoあたりやっています</p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=__syumai" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/syumai" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#     </tbody>
#
#   </table>
# </div>
#
# <div class="applicant_area">
# <h3 class="title_bg mb_20">イベント申込者</h3>
#
#
#
#
#
#
#
# <a name="participants"><h3 class="title_3">参加者一覧</h3></a>
#
#
#
#     <div class="participation_table_area mb_20">
#       <table class="common_table participants_table padding_10">
#         <thead>
#           <tr>
#             <th colspan="2">
#               <span class="label_ptype_name">わいわいする枠</span>
#               参加者
#               <span class="participants_count">25人</span></th>
#           </tr>
#         </thead>
#         <tbody>
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/chiroruxx/">
#
#             <img src="https://media.connpass.com/thumbs/fe/b1/feb1b52f9c521bda8524768f806755fa.png" alt="ちひろ" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/chiroruxx/">ちひろ</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/sgash708/">
#
#             <img src="https://media.connpass.com/thumbs/82/b8/82b8240f70a8aeead790a028601b7aa1.png" alt="Sugar Sato" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/sgash708/">Sugar Sato</a>
#
#
#       </p>
#       <p class="user_profile">SWE</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=satoIsSugar" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/sgash708" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/otakakot/">
#
#             <img src="https://media.connpass.com/thumbs/65/92/65929cfa046ecf845c723ebcc276eb34.png" alt="おーたかこーたろー" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/otakakot/">おーたかこーたろー</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=otakakot" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/otakakot" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/BoriProg/">
#
#             <img src="https://connpass.com/static/img/common/user_no_image.gif" alt="BoriProg" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/BoriProg/">BoriProg</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/mmegmogm/">
#
#             <img src="https://media.connpass.com/thumbs/83/d1/83d1ef2af311516da454e8cae1408246.png" alt="mmegmogm" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/mmegmogm/">mmegmogm</a>
#
#
#       </p>
#       <p class="user_profile">ああ40にして緊急事態なご時世で転職キメたレア人生よ。Ad Techなエンジニア。</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=mmegmogm" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/m-megmog-m" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/logica0419/">
#
#             <img src="https://media.connpass.com/thumbs/e4/a4/e4a495a9863cea35601f65f4dbd5a678.png" alt="logica / Takuto Nagami" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/logica0419/">logica / Takuto Nagami</a>
#
#
#       </p>
#       <p class="user_profile">Software Engineer | Singer | Composer | Designer</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=logica0419" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/logica0419" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/takak2166/">
#
#             <img src="https://media.connpass.com/thumbs/ed/14/ed144fc56ef76b6dcb87ee845047e2fd.png" alt="kashiwa" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/takak2166/">kashiwa</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/takak2166" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/shion1305/">
#
#             <img src="https://media.connpass.com/thumbs/71/f2/71f25d18e3a17ee8ef91a7a12012d2a7.png" alt="Shion1305" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/shion1305/">Shion1305</a>
#
#
#       </p>
#       <p class="user_profile">YNU環境情報学府修士1年</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=shion1305" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/Shion1305" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/mazrean/">
#
#             <img src="https://media.connpass.com/thumbs/fe/ea/feea2249ba998f00e8223630fe4c024c.png" alt="mazrean" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/mazrean/">mazrean</a>
#
#
#       </p>
#       <p class="user_profile">デジタル創作同好会traPでGoを使ってサーバーサイド開発をしている大学院生。</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=mazrean22" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/mazrean" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/matumoto1234/">
#
#             <img src="https://media.connpass.com/thumbs/be/86/be86f690ec25d21a25d257a7352135bc.png" alt="matumoto" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/matumoto1234/">matumoto</a>
#
#
#       </p>
#       <p class="user_profile">こんにちは～</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=matumoto_1234" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/matumoto1234" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/furudono/">
#
#             <img src="https://media.connpass.com/thumbs/28/fc/28fc93ed6f1337f2e01797e3375545a4.png" alt="Furudono" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/furudono/">Furudono</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=furudono2" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/naoyafurudono" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/yuyu_hf/">
#
#             <img src="https://media.connpass.com/thumbs/fd/df/fddfa35b9032682c0e8159b5e49bcc2a.png" alt="yuyu_hf" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/yuyu_hf/">yuyu_hf</a>
#
#
#       </p>
#       <p class="user_profile">大学院生。 C, Python</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=yuyu_hf" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/makki_d/">
#
#             <img src="https://media.connpass.com/thumbs/c6/af/c6afe32ccb145c27f6dd0bafef08ef16.png" alt="MakKi" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/makki_d/">MakKi</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/nmatsumoto4/">
#
#             <img src="https://media.connpass.com/thumbs/4c/d0/4cd02e74804f71b52c0fddfe73da4aaf.png" alt="nmatsumoto4" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/nmatsumoto4/">nmatsumoto4</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#           <span><img src="https://connpass.com/static/img/common/icon_facebook.png" alt="facebook" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/nmatsumoto4" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/tommy_710/">
#
#             <img src="https://connpass.com/static/img/common/user_no_image.gif" alt="tommy_710" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/tommy_710/">tommy_710</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=tomi_t0mmy" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/syumai/">
#
#             <img src="https://media.connpass.com/thumbs/1c/c4/1cc4a993fa40fe5eb529f261e4387bfc.png" alt="syumai" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/syumai/">syumai</a>
#
#
#       </p>
#       <p class="user_profile">Go, React, Denoあたりやっています</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=__syumai" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/syumai" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/Shuhei-pp/">
#
#             <img src="https://media.connpass.com/thumbs/ea/27/ea277ebfe6e43803cfaa1d8211154260.png" alt="Shuhei-pp" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/Shuhei-pp/">Shuhei-pp</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/Shuhei-pp" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/K-Kizuku/">
#
#             <img src="https://media.connpass.com/thumbs/25/18/25189afcd0f4bf5f4fe02559cf2eebcb.png" alt="Kizuku" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/K-Kizuku/">Kizuku</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=Kizuku_tech" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/K-Kizuku" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/mochi2225/">
#
#             <img src="https://media.connpass.com/thumbs/e5/2e/e52e266274000c4a3186a2a42bf256a3.png" alt="もっちー" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/mochi2225/">もっちー</a>
#
#
#       </p>
#       <p class="user_profile">長野県 / 大学4年</p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=mochi_2225" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/mochi-yu" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/kozennoki6/">
#
#             <img src="https://media.connpass.com/thumbs/0b/8d/0b8d124dbd228f917a5f34ec12146f8e.png" alt="然" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/kozennoki6/">然</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/_sunnyone/">
#
#             <img src="https://media.connpass.com/thumbs/35/3a/353ad2d6b2ed74c885243008ca3cdf0f.png" alt="_sunnyone" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/_sunnyone/">_sunnyone</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=_sunnyone" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
# ...
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/shimabox" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/kasaitakeo/">
#
#             <img src="https://media.connpass.com/thumbs/e4/d3/e4d308048d1ecdff32bc3a5692901543.png" alt="takemaru" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/kasaitakeo/">takemaru</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=takemaru_fit" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <a href="https://github.com/take0fit" target="_blank" title="GitHubを見る" class="last"><img src="https://connpass.com/static/img/common/icon_github.png" alt="GitHubを見る" width="20" height="20" /></a>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/Yjue/">
#
#             <img src="https://media.connpass.com/thumbs/61/44/61444b75b57966b2ee1b1840c82daef3.png" alt="NRT(Narita)" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           参加者
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/Yjue/">NRT(Narita)</a>
#
#
#       </p>
#       <p class="user_profile"></p>
#     </div>
#
#       <div class="comment">Go Connect #7 に参加を申し込みました！</div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#         <span title="X(Twitter)未連携"><img src="https://connpass.com/static/img/common/icon_gray_twitter.png" alt="X(Twitter)未連携" width="20" height="20" /></span>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#         </tbody>
#       </table>
#     </div>
#
#
#
#
#
#
#
#
# <a name="cancelled"><h3 class="title_3">キャンセル一覧</h3></a>
#
#
#
#     <div class="cancelled_table_area mb_20">
#       <table class="common_table participants_table padding_10">
#         <thead>
#           <tr>
#             <th colspan="2">
#               <span class="label_ptype_name">わいわいする枠</span>
#               キャンセル
#               <span class="participants_count">2人</span></th>
#           </tr>
#         </thead>
#         <tbody>
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/ma_dash/">
#
#             <img src="https://media.connpass.com/thumbs/02/90/02904e19c3dd88efeee3d24bcf369756.png" alt="MasahiroMiyata" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           キャンセル
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/ma_dash/">MasahiroMiyata</a>
#
#
#       </p>
#       <p class="user_profile">システムエンジニアをしながら、めちゃモテSEプロジェクトの運営してます！！めちゃモテSEとは、...</p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=ma_dash" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#           <span><img src="https://connpass.com/static/img/common/icon_facebook.png" alt="facebook" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#
#
# <tr>
#   <td class="user">
#     <div class="user_info">
#
#
#         <a class="image_link" href="https://connpass.com/user/tsurutaaaaaa_/">
#
#             <img src="https://media.connpass.com/thumbs/e8/c3/e8c36c080e5a549f9f9b18f0883cd965.png" alt="zztkm" width="36" height="36">
#
#         </a>
#
#
#
#
#
#       <span class="label_ptype_name">わいわいする枠</span>
#
#       <span class="label_status_tag">
#
#           キャンセル
#
#       </span>
#
#
#       <p class="display_name">
#
#
#             <a href="https://connpass.com/user/tsurutaaaaaa_/">zztkm</a>
#
#
#       </p>
#       <p class="user_profile">熊本高専卒 / Vim ,Neovim / 鉄拳7 / ドラクエ / CoD</p>
#     </div>
#
#   </td>
#   <td class="social text_center">
#
#
#
#
#
#           <a href="https://twitter.com/intent/user?screen_name=zztkm" target="_blank" title="X(Twitter)を見る"><img src="https://connpass.com/static/img/common/icon_twitter.png" alt="X(Twitter)を見る" width="20" height="20" /></a>
#
#
#
#
#
#         <span title="facebook未連携"><img src="https://connpass.com/static/img/common/icon_gray_facebook.png" alt="facebook未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#         <span title="GitHub未連携" class="last"><img src="https://connpass.com/static/img/common/icon_gray_github.png" alt="GitHub未連携" width="20" height="20" /></span>
#
#
#
#
#
#
#
#
#   </td>
# </tr>
#
#
#
#         </tbody>
#       </table>
#     </div>
#
#
#
#
#
#
#
# </div>
#
#       </div>
#
#
#     <div id="side_area">
#
#
#
# <div class="side_box side_border_area series_area">
#
#   <h2 class="title">グループ情報</h2>
#   <p class="series_title"><a href="https://gotalk.connpass.com/">GoConnect</a></p>
#   <p class="series_sub_title"></p>
#
#   <div class="d-flex">
#     <a href="https://gotalk.connpass.com/" class="image_link"><img src="https://media.connpass.com/thumbs/ea/a5/eaa50ab0fd819d4b97532c343c1b4399.png" width="72" height="48" alt="このグループのイメージ画像" /></a>
#     <table>
#       <tbody>
#         <tr>
#           <th>メンバー数</th>
#           <td><a href="https://gotalk.connpass.com/participation/">213人</a></td>
#         </tr>
#         <tr>
#           <th>イベント数</th>
#           <td><a href="https://gotalk.connpass.com/event/">12回</a></td>
#         </tr>
#       </tbody>
#     </table>
#   </div>
#
#
#
#       <h4>過去のイベント</h4>
#       <ul class="common_ul">
#
#         <li><a href="https://gotalk.connpass.com/event/350324/">Go Connect #6</a></li>
#
#         <li><a href="https://gotalk.connpass.com/event/348827/">Go Connect #5.1 ~『Go言語 100 Tips』を読む会</a></li>
#
#       </ul>
#
#
#
# </div>
#
#
# <div class="side_box side_border_area is_help">
#   <h2 class="side_title">参加者と交流するには？</h2>
#
#   <h3 class="side_subtitle">
#
#       <a href="https://connpass.com/settings/">設定ページ</a>からX(Twitter)やFacebookと連携してみましょう！
#
#   </h3>
#   <p class="mb_10">お友達がイベントを開催したり、イベントを申し込んだりすると、メールで通知がきたり、トップページに表示されたりします。</p>
#   <hr class="mb_10">
#   <p class="text_right"><span class="icon_to_guide"><a href="https://help.connpass.com/basic/settings" target="_blank">詳しくはこちら</a></span></p>
# </div>
#
#
#
#
#
#     </div>
#
#   </div>
#
# </div>
#
#
#
#
#   <div id="footer">
#     <div class="footer_link_area">
#       <div class="layout_column_4 footer_site">
#         <div class="mb_5"><a href="https://connpass.com/" title="サイトのトップページへ"><img src="https://connpass.com/static/img/common/sitelogo_295x100.png" alt="connpass" class="connpass">エンジニアをつなぐ<br>IT勉強会支援プラットフォーム</a></div>
#         <a href="http://twitter.com/connpass_jp" target="_blank" class="mr_5"><img src="https://connpass.com/static/img/common/icon_twitter_official.png" alt="X(Twitter)公式アカウント"></a>
#         <a href="http://www.facebook.com/connpass" target="_blank"><img src="https://connpass.com/static/img/common/icon_facebook_official.png" alt="Facebookページ"></a>
#
#       </div>
#       <div class="layout_column_4 footer_help">
#         <ul class="cmn_list">
#           <li><a href="https://help.connpass.com/" target="_blank" title="connpassのヘルプ">ご利用ガイド</a></li>
#           <li><a href="https://help.connpass.com/faq" target="_blank">よくある質問</a></li>
#           <li><a href="https://connpass.com/inquiry/">connpassへのお問い合わせ</a></li>
#           <li><a href="https://help.connpass.com/faq/advertisement.html" target="_blank">広告掲載</a></li>
#           <li><a href="https://connpass.com/term/">利用規約</a></li>
#           <li><a href="https://www.beproud.jp/company/" target="_blank">運営会社</a></li>
#           <li><a href="https://connpass.com/about/api/v2/" target="_blank">API</a></li>
#           <li><a href="https://connpass.com/law/">特定商取引法に基づく表示</a></li>
#           <li><a href="https://connpass.com/privacy/">プライバシーポリシー</a></li>
#         </ul>
#       </div>
#       <div class="layout_column_4 footer_sns">
#       <ul class="cmn_list">
#         <li class="li_icon_hint"><a href="https://connpass.com/about/" title="connpassの機能をタイムライン風に紹介">機能紹介</a></li>
#         <li class="li_icon_hint"><a href="https://connpass.com/about/comparison/" title="connpassと他イベントサイトとの機能比較">他サービスとの比較</a></li>
#         <li class="li_icon"><a href="https://connpass.com/explore/">新着イベント</a></li>
#         <li class="li_icon_feed"><a href="https://connpass.com/explore/ja.atom" target="_blank">新着イベントfeed</a></li>
#
#       </ul>
#       </div>
#       <div class="layout_column_4 footer_bppr">
#         <div class="bppr_area">
#           <p class="middle_text mb_20">connpass関連サービス</p>
#           <ul>
#             <li class="mb_15">
#               <a href="https://pyq.jp/" target="_blank">
#                 <img src="https://connpass.com/static/img/bppr/pyq_logo_color.svg" alt="PyQ" title="PyQ" />
#                 <span class="note">Python独学プラットフォーム</span>
#               </a>
#             </li>
#             <li>
#               <a href="https://tracery.jp/" target="_blank">
#                 <img src="https://connpass.com/static/img/bppr/tracery_logo.svg" alt="TRACERY" title="TRACERY" />
#                 <span class="note">システム開発ドキュメントサービス</span>
#               </a>
#             </li>
#           </ul>
#         </div>
#       </div>
#     </div>
#     <div class="footer_link_area">
#       <div class="footer_beproud"><a href="https://www.beproud.jp/company/" target="_blank"><img src="https://connpass.com/static/img/common/logo_beproud.png" alt="BePROUD" title="BePROUD" />connpass は株式会社ビープラウドが開発・運営しています</a></div>
#       <address>&copy; 2025 <a href="https://www.beproud.jp/company/" target="_blank">Beproud, Inc.</a> All Rights Reserved.</address>
#     </div>
#   </div>
#
#
# </div>
#
#
#
#
#
# <script id="EventCreateTemplate" type="text/html">
#   <div class="popup">
#     <div class="popup_wrapper">
#       <div class="popup_header">
#         <h2 class="popup_title">イベントを作成する</h2>
#         <span class="close_btn_area">
#           <span class="btn btn_default btn_size_small corner_none modal-close" title="閉じる"><span class="icon_black_close"></span></span>
#         </span>
#       </div>
#       <div class="popup_contents text_center">
#         <p class="font_16 mb_10"><strong>イベント名を入力してください</strong></p>
#         <input name="title" type="text" class="form_input_text form_width_450 font_18">
#         <input type="hidden" name="allow_conflict_join" value="true">
#         <div class="mt_10 mb_30">
#           <button type="submit" class="EventCreateSubmit btn btn_action btn_size_large">イベントを作成</button>
#         </div>
#         <div class="right">
#           <a href="https://connpass.com/group/new/"><span class="icon_red_four_right"></span>グループを作成</a>
#         </div>
#       </div>
#     </div>
#   </div>
# </script>
#
# <script id="MessageTemplate" type="text/html">
#   <p class="message <%= level %>"><%- message %></p>
# </script>
#
#
# <div id="fb-root"></div>
#
#
#
# <div id="CurrentUserObj" style="display:none;" ></div>
# <div id="CSRFToken" style="display:none;" data-csrftoken="RRDNTC9LPznM89jmTXIy7f5BatOCXYJ1UC6vTKqqEX2DwEL84JGc0XLBmvJUokc1"></div>
#
#
# <script type="text/javascript" src="//d-cache.microad.jp/js/td_cnp_access.js"></script>
# <script type="text/javascript">
#
#   microadTd.CNP.start({"article_keyword": ["Go\u8a00\u8a9e", "Go", "IDE", "\u30a8\u30c7\u30a3\u30bf", "\u8a3c\u660e\u66f8", "\u30a2\u30fc\u30ad\u30c6\u30af\u30c1\u30e3", "\u30d5\u30ea\u30fc\u30e9\u30f3\u30b9"]})
#
# </script>
#
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PJVQZGK"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
# <script defer src="https://connpass.com/static/js/htmx@2.0.0.min.js?20250605010849
# "></script>
# <script type="text/javascript" src="https://connpass.com/static/js/require.js?20250605010849
# "></script>
# <script type="text/javascript" src="https://connpass.com/static/js/connpass.min.js?20250605010849
# "></script>
# <script type="text/javascript">
# require.config({
#
#   baseUrl: 'https://connpass.com/static/js/',
#   locale: 'ja',
#
#   config: {
#     'csrf': {
#       CSRF_COOKIE_NAME: 'connpass-csrftoken'
#     },
#     'sanca': {
#
#       LOG_LEVEL: "WARNING",
#       HTTP_HOST: 'connpass.com',
#       STATIC_URL: 'https://connpass.com/static/',
#       MEDIA_URL: 'https://connpass.com/media/',
#       API_BASE_URL: 'https://gotalk.connpass.com/api'
#     }
#   }
# });
# </script>
#
#
# <script type="text/javascript">
#   require([
#     'jquery', 'jquerytools/tooltip.dynamic',
#     'jquerytools/tooltip.slide', 'design'
#   ], function($, Views) {
#     $(function() {
#       $('.Help').tooltip({
#         effect: 'slide',
#         position: 'bottom center',
#         offset: [20, 0],
#       }).dynamic({
#         bottom: {
#           direction: 'down',
#           bounce: true
#         }
#       });
#     });
#   });
#
#
#
#   require(['jquery', 'cs!sanca/views/personal_menu'], function($, Views) {
#     var personal_menu = new Views.PersonalMenu({
#       el: '#header',
#       dropdown_el: '#personalMenu'
#     });
#   });
#
#
#
#
# </script>
# <script type="text/javascript">
#   window.fbAsyncInit = function() {
#     FB.init({
#       version: 'v20.0',
#       status: true,
#       appId: '259235460759625',
#       xfbml: true  // Like btn
#     });
#   };
#
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "//connect.facebook.net/ja_JP/sdk.js";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
# </script>
# <script>require(['htmx/show_messages'], function(handleShowMessages) { handleShowMessages(); });</script>
#
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
from collections import defaultdict

# HTML取得
url = "https://gotalk.connpass.com/event/355423/participation/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
                   (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}
res = requests.get(url, headers=headers)
html = res.text

# HTMLをパース
soup = BeautifulSoup(html, "html.parser")

# タグごとに分類
tag_groups = defaultdict(list)

for tag in soup.find_all(True):  # True で全タグ対象
    tag_groups[tag.name].append(tag)

# タグ別に表示
for tag_name, tags in sorted(tag_groups.items()):
    print(f"\n🟦 <{tag_name}> タグ: {len(tags)} 件")
    for tag in tags[:5]:  # 最初の5つだけ表示（多すぎるとき用）
        print(f"  {str(tag)[:100]}...")
# Out:
# 🟦 <a> タグ: 147 件
#   <a href="https://connpass.com/" title="connpass - エンジニアをつなぐIT勉強会支援プラットフォーム"><img alt="connpass - エンジ...
#   <a href="https://connpass.com/explore/">新着イベント</a>...
#   <a class="btn btn_default login" href="https://connpass.com/login/">ログイン・新規登録</a>...
#   <a href="https://connpass.com/event/355423/" title="Go Connect #7">
# <img alt="Go Connect #7" height=...
#   <a class="event_title" href="https://gotalk.connpass.com/event/355423/"><span class="icon_red_four_r...
#
# 🟦 <address> タグ: 1 件
#   <address>© 2025 <a href="https://www.beproud.jp/company/" target="_blank">Beproud, Inc.</a> All Righ...
#
# 🟦 <body> タグ: 1 件
#   <body class="event_participation" hx-headers='{"X-CSRFToken": "caiPimaJtV7ZpPTdblmXGMtyP24mMmBUiafHi...
#
# 🟦 <br> タグ: 1 件
#   <br/>...
#
# 🟦 <button> タグ: 1 件
#   <button class="btn btn_default btn_size_small" type="submit"><img alt="イベント検索" src="https://connpass...
#
# 🟦 <div> タグ: 93 件
#   <div class="lang_ja" id="wrapper">
# <div id="header">
# <div class="container">
# <h1><a href="https://co...
#   <div id="header">
# <div class="container">
# <h1><a href="https://connpass.com/" title="connpass - エンジニ...
#   <div class="container">
# <h1><a href="https://connpass.com/" title="connpass - エンジニアをつなぐIT勉強会支援プラットフォ...
#   <div class="header_search">
# <input class="form_input_text" id="id_q" name="q" placeholder="イベント検索" t...
#   <div class="header_nav_contents">
# <ul>
# <li><a href="https://connpass.com/explore/">新着イベント</a></li>
# <...
#
# 🟦 <form> タグ: 1 件
#   <form action="https://connpass.com/search/" id="header_event_search_form" method="GET">
# <div class="...
#
# 🟦 <h1> タグ: 1 件
#   <h1><a href="https://connpass.com/" title="connpass - エンジニアをつなぐIT勉強会支援プラットフォーム"><img alt="connpass -...
#
# 🟦 <h2> タグ: 3 件
#   <h2 class="page_title">イベント参加者・申込者一覧</h2>...
#   <h2 class="title">グループ情報</h2>...
#   <h2 class="side_title">参加者と交流するには？</h2>...
#
# 🟦 <h3> タグ: 5 件
#   <h3 class="title_bg mb_10">イベント関係者</h3>...
#   <h3 class="title_bg mb_20">イベント申込者</h3>...
#   <h3 class="title_3">参加者一覧</h3>...
#   <h3 class="title_3">キャンセル一覧</h3>...
#   <h3 class="side_subtitle">
# <a href="https://connpass.com/settings/">設定ページ</a>からX(Twitter)やFacebookと連...
#
# 🟦 <h4> タグ: 1 件
#   <h4>過去のイベント</h4>...
#
# 🟦 <head> タグ: 1 件
#   <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" ...
#
# 🟦 <hr> タグ: 1 件
#   <hr class="mb_10"/>...
#
# 🟦 <html> タグ: 1 件
#   <html lang="ja" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <...
#
# 🟦 <iframe> タグ: 1 件
#   <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJVQZGK" style="display:none...
#
# 🟦 <img> タグ: 146 件
#   <img alt="connpass - エンジニアをつなぐIT勉強会支援プラットフォーム" class="logo" src="https://connpass.com/static/img/com...
#   <img alt="イベント検索" src="https://connpass.com/static/img/common/icon_search.png"/>...
#   <img alt="Go Connect #7" height="48" src="https://media.connpass.com/thumbs/4d/4b/4d4b83b92b8ac11b23...
#   <img alt="ちひろ" height="36" src="https://media.connpass.com/thumbs/fe/b1/feb1b52f9c521bda8524768f8067...
#   <img alt="X(Twitter)未連携" height="20" src="https://connpass.com/static/img/common/icon_gray_twitter.p...
#
# 🟦 <input> タグ: 3 件
#   <input class="form_input_text" id="id_q" name="q" placeholder="イベント検索" type="text" value=""/>...
#   <input name="start_from" type="hidden" value="2025/06/08"/>...
#   <input name="start_to" type="hidden" value="2025/12/08"/>...
#
# 🟦 <li> タグ: 18 件
#   <li><a href="https://connpass.com/explore/">新着イベント</a></li>...
#   <li><a href="https://gotalk.connpass.com/event/350324/">Go Connect #6</a></li>...
#   <li><a href="https://gotalk.connpass.com/event/348827/">Go Connect #5.1 ~『Go言語 100 Tips』を読む会</a></li...
#   <li><a href="https://help.connpass.com/" target="_blank" title="connpassのヘルプ">ご利用ガイド</a></li>...
#   <li><a href="https://help.connpass.com/faq" target="_blank">よくある質問</a></li>...
#
# 🟦 <link> タグ: 4 件
#   <link href="https://connpass.com/static/css/connpass.css?20250605010849
# " media="all" rel="styleshee...
#   <link href="https://connpass.com/static/img/favicon.ico" rel="shortcut icon" type="image/vnd.microso...
#   <link href="https://connpass.com/static/img/apple_touch_icon.png" rel="apple-touch-icon-precomposed"...
#   <link as="style" href="https://fonts.googleapis.com/css?family=Montserrat&amp;display=swap" onload="...
#
# 🟦 <meta> タグ: 14 件
#   <meta charset="utf-8"/>...
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>...
#   <meta content="connpass,コンパス,イベント,IT勉強会,検索,開催,募集,参加,ソーシャル連携,アクセス解析,手数料無料" name="keywords">
# <meta con...
#   <meta content="「Go Connect #7」の参加者・申込者の一覧です。" name="description">
# <title>Go Connect #7 - 参加者・申込者一覧 -...
#   <meta content="website" property="og:type"/>...
#
# 🟦 <noscript> タグ: 1 件
#   <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJVQZGK" style="di...
#
# 🟦 <p> タグ: 74 件
#   <p>広告</p>...
#   <p class="display_name">
# <a href="https://connpass.com/user/chiroruxx/open/">ちひろ</a>
# </p>...
#   <p class="user_profile"></p>...
#   <p class="display_name">
# <a href="https://connpass.com/user/sgash708/open/">Sugar Sato</a>
# </p>...
#   <p class="user_profile">SWE</p>...
#
# 🟦 <script> タグ: 20 件
#   <script type="text/javascript">
#   if (typeof console == "undefined") {window.console={log: function ...
#   <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'g...
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbyg...
#   <script src="//anymind360.com/js/279/ats.js" type="application/javascript"></script>...
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>...
#
# 🟦 <small> タグ: 1 件
#   <small>（connpassユーザーのみ表示しています）</small>...
#
# 🟦 <span> タグ: 123 件
#   <span class="thumbnail">
# <a href="https://connpass.com/event/355423/" title="Go Connect #7">
# <img al...
#   <span class="icon_red_four_right"></span>...
#   <span class="participants_count">2人</span>...
#   <span title="X(Twitter)未連携"><img alt="X(Twitter)未連携" height="20" src="https://connpass.com/static/im...
#   <span title="facebook未連携"><img alt="facebook未連携" height="20" src="https://connpass.com/static/img/co...
#
# 🟦 <table> タグ: 4 件
#   <table class="common_table participants_table padding_10">
# <thead>
# <tr>
# <th colspan="2">管理者<span cla...
#   <table class="common_table participants_table padding_10">
# <thead>
# <tr>
# <th colspan="2">
# <span class...
#   <table class="common_table participants_table padding_10">
# <thead>
# <tr>
# <th colspan="2">
# <span class...
#   <table>
# <tbody>
# <tr>
# <th>メンバー数</th>
# <td><a href="https://gotalk.connpass.com/participation/">214人</a...
#
# 🟦 <tbody> タグ: 5 件
#   <tbody>
# <tr>
# <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass....
#   <tbody>
# <tr>
# <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass....
#   <tbody>
# <tr>
# <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass....
#   <tbody>
# <tr>
# <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass....
#   <tbody>
# <tr>
# <th>メンバー数</th>
# <td><a href="https://gotalk.connpass.com/participation/">214人</a></td>
# <...
#
# 🟦 <td> タグ: 70 件
#   <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass.com/user/chir...
#   <td class="social text_center">
# <span title="X(Twitter)未連携"><img alt="X(Twitter)未連携" height="20" src...
#   <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass.com/user/sgas...
#   <td class="social text_center">
# <a href="https://twitter.com/intent/user?screen_name=satoIsSugar" ta...
#   <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass.com/user/otak...
#
# 🟦 <th> タグ: 6 件
#   <th colspan="2">管理者<span class="participants_count">2人</span></th>...
#   <th colspan="2">
#
#             発表者<span class="participants_count">5人</span>
# <small>（connpa...
#   <th colspan="2">
# <span class="label_ptype_name">わいわいする枠</span>
#               参加者
#               <span...
#   <th colspan="2">
# <span class="label_ptype_name">わいわいする枠</span>
#               キャンセル
#               <sp...
#   <th>メンバー数</th>...
#
# 🟦 <thead> タグ: 4 件
#   <thead>
# <tr>
# <th colspan="2">管理者<span class="participants_count">2人</span></th>
# </tr>
# </thead>...
#   <thead>
# <tr>
# <th colspan="2">
#
#             発表者<span class="participants_count">5人</span>
# <...
#   <thead>
# <tr>
# <th colspan="2">
# <span class="label_ptype_name">わいわいする枠</span>
#               参加者
#       ...
#   <thead>
# <tr>
# <th colspan="2">
# <span class="label_ptype_name">わいわいする枠</span>
#               キャンセル
#     ...
#
# 🟦 <title> タグ: 1 件
#   <title>Go Connect #7 - 参加者・申込者一覧 - connpass</title>...
#
# 🟦 <tr> タグ: 40 件
#   <tr>
# <th colspan="2">管理者<span class="participants_count">2人</span></th>
# </tr>...
#   <tr>
# <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass.com/user...
#   <tr>
# <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass.com/user...
#   <tr>
# <th colspan="2">
#
#             発表者<span class="participants_count">5人</span>
# <small>（c...
#   <tr>
# <td class="user">
# <div class="user_info">
# <a class="image_link" href="https://connpass.com/user...
#
# 🟦 <ul> タグ: 5 件
#   <ul>
# <li><a href="https://connpass.com/explore/">新着イベント</a></li>
# </ul>...
#   <ul class="common_ul">
# <li><a href="https://gotalk.connpass.com/event/350324/">Go Connect #6</a></li...
#   <ul class="cmn_list">
# <li><a href="https://help.connpass.com/" target="_blank" title="connpassのヘルプ">...
#   <ul class="cmn_list">
# <li class="li_icon_hint"><a href="https://connpass.com/about/" title="connpass...
#   <ul>
# <li class="mb_15">
# <a href="https://pyq.jp/" target="_blank">
# <img alt="PyQ" src="https://connp...
